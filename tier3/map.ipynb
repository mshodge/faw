# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('teams.csv')
df

# Make an empty map
m = folium.Map(location=[52.458971, -3.381157], tiles="CartoDB positron", zoom_start=8)
 
    
colordict = {'South East': 'lightblue', 'South West': 'lightgreen', 'North East': 'orange', 'North West': 'red'}
    
# I can add marker one by one on the map
for lat, lon, team, league in zip(df['lat'], df['lon'], df['Team'], df['League']):
   folium.CircleMarker(
      location=[lat, lon],
      radius=5,
       stroke=True,
       popup=team,
       color='black',
       opacity=1,
       weight=1,
       fill=True,
      fill_color=colordict[league],
       fill_opacity=1
   ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save(outfile= "tier3_teams.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-5ac12b7502af> in <module>
# ----> 1 saveWidget(m, file="tier3_teams.html")
#
# NameError: name 'saveWidget' is not defined
